# %% [markdown]
# # convert errrors to files

# %%
# !pwd
# Out:
# /home/amin/code/etiv/git/back/docs/responses/errors

# %%
# !rm *.json
# !ls
# Out:
# 'convert errrors to files.ipynb'

# %%
reses = reses = {
        
        '00001' : {
            'message' : 'Unknown error!',
            'shortener' : 'bad_request',
        },
        '00002' : {
            'message' : 'Method not allowed!',
            'shortener' : 'method_not_allowed',
        },
        '00003' : {
            'message' : 'Not found!',
            'shortener' : 'not_found',
        },
        '00004' : {
            'message' : 'Invalid Input For Submit',
            'shortener' : 'bad_request',
        },


        
        '10001' : {
            'message' : 'User does not exist!',
            'shortener' : 'not_authorized',
        },

        '10002' : {
            'message' : 'User does not exist!',
            'shortener' : 'unprocessable_request',
        },

         '10003' : {
             'message' : 'User Have not Access',
             'shortener' : 'not_authorized',
         },

         '10004' : {
             'message' : 'You can not change your role',
             'shortener' : 'bad_request',
         },

         '10005' : {
             'message' : 'Your Token is invalid for change password',
             'shortener' : 'not_found',
         },

         '10006' : {
             'message' : 'This request expired send new rest password',
             'shortener' : 'bad_request',
         },
         '10007' : {
             'message' : 'User Activation Token Not Found in System',
             'shortener' : 'not_found',
         },

         '10008' : {
             'message' : 'User account already is valid',
             'shortener' : 'forbidden',
         },




        '11001' : {
            'message' : 'User does not exist!',
            'shortener' : 'not_found',
        },
        '11002' : {
            'message' : 'E-Mail sending not possible!',
            'shortener' : 'unprocessable_request',
        },

        '11003' : {
            'message' : 'You have not access',
            'shortener' : 'not_authorized',
        },


        '11004' : {
            'message' : 'invalid Inputs',
            'shortener' : 'bad_request',
        },


        '11005' : {
            'message' : 'Certificate Id Not valid',
            'shortener' : 'bad_request',
        },


        '11006' : {
            'message' : 'certificate is not valid',
            'shortener' : 'bad_request',
        },

        '11007' : {
            'message' : 'Certificate user id is not valid',
            'shortener' : 'bad_request',
        },

        '11008' : {
            'message' : 'Owner of Certificate id is different ',
            'shortener' : 'unprocessable_request',
        },


        '11009' : {
            'message' : 'phone number of user not set yet',
            'shortener' : 'bad_request',
        },


        '11010' : {
            'message' : 'You can not transfer to your self',
            'shortener' : 'unprocessable_request',
        },

        '11011' : {
            'message' : 'lenght is not valid',
            'shortener' : 'unprocessable_request',
        },

        '11012' : {
            'message' : 'Can not submit transfer request to system',
            'shortener' : 'server',
        },


        '11013' : {
            'message' : 'Can not send to your phone pin code',
            'shortener' : 'server',
        },


        '11014' : {
            'message' : 'Your Request number is not valid',
            'shortener' : 'bad_request',
        },

        '11015' : {
            'message' : 'You try 3 time or your request expired',
            'shortener' : 'unprocessable_request',
        },

        '11016' : {
            'message' : 'pin code not valid',
            'shortener' : 'unprocessable_request',
        },


        '11017' : {
            'message' : 'request time out. please request agian',
            'shortener' : 'unprocessable_request',
        },

        '11018' : {
            'message' : 'certificate Id not Exist in System',
            'shortener' : 'unprocessable_request',
        },

        '11019' : {
            'message' : 'contract is not valid',
            'shortener' : 'unprocessable_request',
        },

        '11020' : {
            'message' : 'contract is in transfer please check later',
            'shortener' : 'unprocessable_request',
        },

        '11021' : {
            'message' : 'Owner of Certificate id is diffrent',
            'shortener' : 'not_authorized',
        },

        '11022' : {
            'message' : 'You can not transfer to your self',
            'shortener' : 'unprocessable_request',
        },

        '11023' : {
            'message' : 'can not tranfert to candidate user',
            'shortener' : 'bad_request',
        },

        '11024' : {
            'message' : 'can not create pdf',
            'shortener' : 'server',
        },

        '11025' : {
            'message' : 'can not create new certificate for transfer',
            'shortener' : 'server',
        },

        '11026' : {
            'message' : 'you have not matrial',
            'shortener' : 'unprocessable_request',
        },


        '11027' : {
            'message' : 'can not send email',
            'shortener' : 'server',
        },

        '11028' : {
            'message' : 'Certificate user id is not valid',
            'shortener' : 'server',
        },
        '11029' : {
            'message' : 'Transform type not valid',
            'shortener' : 'unprocessable_request',
        },

        '11030' : {
            'message' : 'Transfer ID and Certificate ID is not correct',
            'shortener' : 'unprocessable_request',
        },

        '11031' : {
            'message' : 'this cut can not happend',
            'shortener' : 'unprocessable_request',
        },







        '12001' : {
            'message' : 'please select correct addon number.',
            'shortener' : 'bad_request',
        },

        '12002' : {
            'message' : 'please select correct shape.{bar or cube}',
            'shortener' : 'bad_request',
        },

        '12003' : {
            'message' : 'this type is not valid',
            'shortener' : 'bad_request',
        },

        '12004' : {
            'message' : 'certificate file is more than 10 mB',
            'shortener' : 'large_file',
        },

        '12005' : {
            'message' : 'certificate file not .PDF',
            'shortener' : 'media_type',
        },

        '12006' : {
            'message' : 'can not upload adonn files',
            'shortener' : 'server',
        },

        '12007' : {
            'message' : 'invalid Inputs',
            'shortener' : 'bad_request',
        },



        '12008' : {
            'message' : 'addon file is more than 10 mB',
            'shortener' : 'large_file',
        },

        '12009' : {
            'message' : 'addon file not .PDF',
            'shortener' : 'media_type',
        },


        '12010' : {
            'message' : 'can not create pdf',
            'shortener' : 'server',
        },

        '12011' : {
            'message' : 'can not save in database certificate',
            'shortener' : 'server',
        },


        '12012' : {
            'message' : 'can not send email to owner of certificate',
            'shortener' : 'created',
        },

        '12013' : {
            'message' : 'invalid Input',
            'shortener' : 'bad_request',
        },

        '12014' : {
            'message' : 'can not upload original file in clould',
            'shortener' : 'server',
        },

        '12015' : {
            'message' : 'can not handle certificate file and addon files',
            'shortener' : 'server',
        },

        '12016' : {
            'message' : 'Can not Copy Default Certificate File',
            'shortener' : 'server',
        },






        '13001' : {
            'message' : 'this certificate ID is not valid ',
            'shortener' : 'bad_request',
        },

        '13002' : {
            'message' : 'contract is in transfer please check again',
            'shortener' : 'bad_request',
        },

        '13003' : {
            'message' : 'invalid Input',
            'shortener' : 'bad_request',
        },

      
        '14001' : {
            'message' : 'this certificate ID is not valid ',
            'shortener' : 'bad_request',
        },

        '14002' : {
            'message' : 'can not save in data base',
            'shortener' : 'server',
        },

        '14003' : {
            'message' : 'can not send email',
            'shortener' : 'server',
        },

        '14004' : {
            'message' : 'invalid Inputs',
            'shortener' : 'bad_request',
        },

       
        '15001' : {
            'message' : 'invalid Input',
            'shortener' : 'bad_request',
        },

        '15002' : {
            'message' : 'can not find certificate',
            'shortener' : 'bad_request',
        },


        '15003' : {
            'message' : 'history is just available for the transferred contracts.',
            'shortener' : 'bad_request',
        },
        '15004' : {
            'message' : 'you are not creator of this certificate',
            'shortener' : 'bad_request',
        },
        '15005' : {
            'message' : 'child certificate not found',
            'shortener' : 'bad_request',
        },


        '16001' : {
            'message' : 'Invalid inputs',
            'shortener' : 'bad_request',
        },

        '16002' : {
            'message' : 'The E-Mail could not be sent!',
            'shortener' : 'unprocessable_request',
        },

        '16003' : {
            'message' : 'this user ID is not valid',
            'shortener' : 'unprocessable_request',
        },

        '16004' : {
            'message' : 'email send to you.',
            'shortener' : 'unprocessable_request',
        },


        '16005' : {
            'message' : 'user not exist',
            'shortener' : 'unprocessable_request',
        },
        '16006' : {
            'message' : 'email send to you.',
            'shortener' : 'unprocessable_request',
        },

       
        '17001' : {
            'message' : 'Invalid inputs',
            'shortener' : 'bad_request',
        },


        '17002' : {
            'message' : 'this certificate id is not valid',
            'shortener' : 'unprocessable_request',
        },

        '17003' : {
            'message' : 'you are not owner of this certificate',
            'shortener' : 'forbidden',
        },

        '17004' : {
            'message' : 'can not update certiricate options',
            'shortener' : 'server',
        },


        '17005' : {
            'message' : 'can not update certiricate',
            'shortener' : 'server',
        },


        '17006' : {
            'message' : 'green options is already seted and can not change',
            'shortener' : 'unprocessable_request',
        },
        '17007' : {
            'message' : 'green options is not valid',
            'shortener' : 'unprocessable_request',
        },
        '17008' : {
            'message' : 'certificate not valid',
            'shortener' : 'unprocessable_request',
        },

        '17009' : {
            'message' : 'template not found',
            'shortener' : 'unprocessable_request',
        },
       
        '18001' : {
            'message' : 'Invalid inputs',
            'shortener' : 'bad_request',
        },


        '18002' : {
            'message' : 'phone number is not valid',
            'shortener' : 'bad_request',
        },

        '18003' : {
            'message' : 'enter valid employees numbers',
            'shortener' : 'bad_request',
        },
        '18004' : {
            'message' : 'can not update user',
            'shortener' : 'server',
        },






        '19001' : {
            'message' : 'Wrong data',
            'shortener' : 'bad_request',
        },

        '19002' : {
            'message' : 'Invalid inputs',
            'shortener' : 'bad_request',
        },


        '19003' : {
            'message' : 'Email already exist!',
            'shortener' : 'conflict',
        },

        '19004' : {
            'message' : 'can not complet sing up.',
            'shortener' : 'server',
        },

        '19005' : {
            'message' : 'Password not mathed',
            'shortener' : 'bad_request',
        },


        '19006' : {
            'message' : 'User Not Exist',
            'shortener' : 'unprocessable_request',
        },


        '19007' : {
            'message' : 'password not correct',
            'shortener' : 'unprocessable_request',
        },



        '19008' : {
            'message' : 'User Not Exist',
            'shortener' : 'unprocessable_request',
        },

        '19009' : {
            'message' : 'Can not send email',
            'shortener' : 'unprocessable_request',
        },


        '19010' : {
            'message' : 'token is not valid',
            'shortener' : 'unprocessable_request',
        },

        '19011' : {
            'message' : 'can not update user password',
            'shortener' : 'server',
        },


        '19012' : {
            'message' : 'can not send email',
            'shortener' : 'server',
        },


        '19013' : {
            'message' : 'can not create token for rest password',
            'shortener' : 'server',
        },

        '19014' : {
            'message' : 'token is expire',
            'shortener' : 'unprocessable_request',
        },


        

        '19015' : {
            'message' : 'token is not found',
            'shortener' : 'unprocessable_request',
        },

        '19016' : {
            'message' : 'can not update account and verify account',
            'shortener' : 'server',
        },

        '19017' : {
            'message' : 'can not send verfication email',
            'shortener' : 'server',
        },
        '19018' : {
            'message' : 'token is expire',
            'shortener' : 'unprocessable_request',
        },

        '19019' : {
            'message' : 'token is expire',
            'shortener' : 'unprocessable_request',
        },

        '19020' : {
            'message' : 'User E-Mail not verified!',
            'shortener' : 'unprocessable_request',
        },

       
        '20001' : {
            'message' : 'error',
            'shortener' : 'unprocessable_request',
        },


        '20002' : {
            'message' : 'Can not send email',
            'shortener' : 'unprocessable_request',
        },

        '20003' : {
            'message' : 'invalid input',
            'shortener' : 'unprocessable_request',
        },

        '20004' : {
            'message' : 'upload fails',
            'shortener' : 'unprocessable_request',
        },
        '20005' : {
            'message' : 'invalid token',
            'shortener' : 'unprocessable_request',
        },
        '20006' : {
            'message' : 'can not save temp file',
            'shortener' : 'server',
        },

        '20007' : {
            'message' : 'file ext not pdf',
            'shortener' : 'unprocessable_request',
        },

        '20008' : {
            'message' : 'file is larger then 10 MegaByte',
            'shortener' : 'unprocessable_request',
        },
        '20009' : {
            'message' : 'can not create pdf file or upload it',
            'shortener' : 'server',
        },

}

# %%
len(reses.items())
# Out:
# 119

# %%
for key , item in reses.items():
   
    json_template = f"""
        "ok":false,
        "error" => "{item['message']}",
        "data" => "",
      """
    json_template = '{'+ json_template + '}'
#     print(json_template)
    with open(f'{key}.json','w') as myfile:
        myfile.write(json_template)

# %%
# %ls
# Out:
#  00001.json   11019.json   13002.json   19001.json
#  00002.json   11020.json   13003.json   19002.json
#  00003.json   11021.json   14001.json   19003.json
#  00004.json   11022.json   14002.json   19004.json
#  10001.json   11023.json   14003.json   19005.json
#  10002.json   11024.json   14004.json   19006.json
#  10003.json   11025.json   15001.json   19007.json
#  10004.json   11026.json   15002.json   19008.json
#  10005.json   11027.json   15003.json   19009.json
#  10006.json   11028.json   15004.json   19010.json
#  10007.json   11029.json   15005.json   19011.json
#  10008.json   11030.json   16001.json   19012.json
#  11001.json   11031.json   16002.json   19013.json
#  11002.json   12001.json   16003.json   19014.json
#  11003.json   12002.json   16004.json   19015.json
#  11004.json   12003.json   16005.json   19016.json
#  11005.json   12004.json   16006.json   19017.json
#  11006.json   12005.json   17001.json   19018.json
# ...
